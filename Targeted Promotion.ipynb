# %%
# Import libraries
import pandas as pd
import numpy as np

# %%
# Import extracted tweets on IoT
data  = pd.read_csv("tweet_iotnew.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11405 entries, 0 to 11404
# Data columns (total 90 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   user_id                  11405 non-null  float64
#  1   status_id                11405 non-null  float64
#  2   created_at               11405 non-null  object
#  3   screen_name              11405 non-null  object
#  4   text                     11405 non-null  object
#  5   source                   11405 non-null  object
#  6   display_text_width       11405 non-null  int64
#  7   reply_to_status_id       201 non-null    float64
#  8   reply_to_user_id         353 non-null    float64
#  9   reply_to_screen_name     353 non-null    object
#  10  is_quote                 11405 non-null  bool
#  11  is_retweet               11405 non-null  bool
#  12  favorite_count           11405 non-null  int64
#  13  retweet_count            11405 non-null  int64
# ...

# %%
data.head()
# Out:
#         user_id     status_id            created_at      screen_name  \
# 0  2.965977e+09  1.245300e+18  2020-04-01T10:49:25Z  whatsthebigdata
# 1  2.965977e+09  1.243540e+18  2020-03-27T14:13:14Z  whatsthebigdata
# 2  2.965977e+09  1.245210e+18  2020-04-01T04:30:23Z  whatsthebigdata
# 3  2.965977e+09  1.244720e+18  2020-03-30T19:56:16Z  whatsthebigdata
# 4  2.965977e+09  1.243770e+18  2020-03-28T05:16:03Z  whatsthebigdata
#
#                                                 text       source  \
# 0  How fresh is your fish? check the date...on th...  SocialOomph
# 1  #Wearable technology &amp; the Internet of Thi...  SocialOomph
# 2  #wearable have you been? #IoT sensors are now ...  SocialOomph
# 3  #ainttalkinboutlove ... but the #edge of #iot....  SocialOomph
# 4  #wearable technology has become edible! Check ...  SocialOomph
#
#    display_text_width  reply_to_status_id  reply_to_user_id  \
# 0                  99                 NaN               NaN
# ...

# %%
# View screen name of top 10 users who tweeted on IoT
print(data['screen_name'].value_counts().head(20))
# Out:
# TheIoT             366
# SuriyaSubraman     256
# IoTBigDataJobs     222
# yowie_bot          222
# gpibot_g           221
# gp_pulipaka        146
# cryptosEUR         135
# cryptosUSD         135
# digital_trans4m    123
# igent_io           121
# software4iot       103
# iotforall          103
# IainLJBrown         99
# BearStoneHA         94
# KirkDBorne          93
# DS_Analytics        93
# Ronald_vanLoon      81
# arjenvanberkum      79
# keepnetlabs         71
# anchoragehouse2     68
# Name: screen_name, dtype: int64
